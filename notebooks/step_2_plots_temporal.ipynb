# %%
import pandas as pd
from src.visualization.plots import (
    heatmap,
    plot_accidents_time_dimensions,
    plot_accidents_traffic,
)

df = pd.read_parquet("../data/processed/traffic_crashes_hourly.parquet")

# %%
heatmap(df)

# %%
plot_accidents_time_dimensions(df)

# %%
plot_accidents_traffic(df)
